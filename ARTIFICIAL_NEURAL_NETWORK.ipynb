# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpak2408/ANN-INFOSYS/blob/main/ARTIFICIAL_NEURAL_NETWORK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data analysis & manipulation
import pandas as pd
# Numerical computation
import numpy as np
# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# Deep learning libraries
import tensorflow as tf
from tensorflow import keras

# %%
mca=pd.read_csv("https://raw.githubusercontent.com/pushpak2408/ANN-INFOSYS/main/Churn_Modelling%20(1).csv")
mca
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
mca.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
mca.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
mca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
mca.shape
# Out:
# (10000, 14)

# %%
mca.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
mca.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
mca.drop(["RowNumber","CustomerId","Surname"], axis=1, inplace=True)

# %%
mca.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# If columns are correct, proceed with get_dummies
mca1 = pd.get_dummies(prefix='dummy',data=mca, columns=["Geography", "Gender"])

# %%
mca1.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  dummy_France  dummy_Germany  \
# 0               1        101348.88       1          True          False
# 1               1        112542.58       0         False          False
# 2               0        113931.57       1          True          False
# 3               0         93826.63       0          True          False
# 4               1         79084.10       0         False          False
#
#    dummy_Spain  dummy_Female  dummy_Male
# 0        False          True       False
# 1         True          True       False
# ...

# %%
mca1.hist(figsize=(15,10))
plt.title("histogram analysis")
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x="Exited",data=mca1)
plt.ylabel("total number of coustomer who left the bank")
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x="HasCrCard",data=mca1)
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.countplot(x="IsActiveMember",data=mca1)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.countplot(x="NumOfProducts",hue="IsActiveMember",data=mca1)
plt.show()

# %%
#preparation of dataset
x=mca1.iloc[:,mca1.columns!="Exited"]
y=mca1.iloc[:,mca1.columns=="Exited"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
print(y_train)
# Out:
#       Exited
# 7389       0
# 9275       0
# 2995       0
# 5316       0
# 356        0
# ...      ...
# 9225       0
# 4859       0
# 3264       0
# 9845       0
# 2732       1
#
# [8000 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

# Initialize the model
classifier = Sequential()

# Adding layers to the model
classifier.add(Dense(units=7, kernel_initializer="uniform", activation="relu", input_dim=13))
classifier.add(Dense(units=7, kernel_initializer="uniform", activation="relu"))
classifier.add(Dense(units=1, kernel_initializer="uniform", activation="sigmoid"))

# Compile the model
classifier.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# Fit the model
classifier.fit(x_train, y_train, batch_size=10, epochs=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7895 - loss: 0.5556
# Epoch 2/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7976 - loss: 0.4274
# Epoch 3/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8014 - loss: 0.4187
# Epoch 4/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8159 - loss: 0.4212
# Epoch 5/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8276 - loss: 0.4139
# Epoch 6/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8292 - loss: 0.4131
# Epoch 7/100
# 800/800 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8279 - loss: 0.4137
# Epoch 8/100
# ...

# %%
y_pread=classifier.predict(x_test)
y_pread=(y_pread>0.5)
print(y_pread)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
print(type(mca1))
from sklearn.ensemble import RandomForestClassifier

mca1 = RandomForestClassifier()
mca1.fit(X_train, y_train)  # Train your model here
y_pread = mca1.predict(X_test)
from sklearn.metrics import confusion_matrix

# Make sure mca1 is your trained model, not a DataFrame
print("Length of y_test:", len(y_test))
print("Length of y_pread:", len(y_pread))

# Ensure y_pread is predicted using the model
y_pread = mca1.predict(X_test)

# Ensure y_test and y_pread have the same length
assert len(y_test) == len(y_pread), "Length mismatch between y_test and y_pread"

# Compute and print confusion matrix
cm = confusion_matrix(y_test, y_pread)
print(cm)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Length of y_test: 30
# Length of y_pread: 30
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
plt.figure(figsize=(5,3))
df_cm = pd.DataFrame(cm)  # Corrected to DataFrame
sns.heatmap(df_cm, annot=True, fmt='d')  # Added annot=True and fmt='d' for better readability
plt.xlabel("Predicted")  # Corrected to xlabel
plt.ylabel("Actual")  # Corrected to ylabel
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris

# Load data and split into train and test sets
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# Train a model
clf = RandomForestClassifier()
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# Ensure y_pred and y_test are defined
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
new_p= classifier.predict(sc.transform(np.array([[608,41,1,83807.86,1,0,1,112542.58,0,0,1,1,0]])))
new_p=(new_p>0.5)
print(new_p)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# [[False]]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pip install imbalanced-learn
